# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('lr00_results.csv')
data.head()

# %%
plt.scatter(data1.x, data1.y, marker='x')
plt.show()

# %%
data1 = pd.read_csv('line1.csv')
data1.head()

# %%
data2 = pd.read_csv('line2.csv')
data2.head()

# %%
data3 = pd.read_csv('line3.csv')
data3.head()

# %%
plt.plot(data1.x, data1.y, c='r')
plt.show()

# %%
plt.plot(data2.x, data2.y, c='g')
plt.show()

# %%
plt.plot(data3.x, data3.y, c='y')
plt.show()

# %%
plt.scatter(data.x, data.y)
plt.plot(data1.x, data1.y, c='r')
plt.plot(data2.x, data2.y, c='g')
plt.plot(data3.x, data3.y, c='y')
plt.legend()
plt.show()
